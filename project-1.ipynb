# %%
import numpy as np
import pandas as pd

# %%
dengue_features_test=pd.read_csv("dengue_features_test.csv")
dengue_features_train= pd.read_csv("dengue_features_train.csv")
dengue_labels_train =pd.read_csv("dengue_labels_train.csv")
# submission_format=pd.read_csv("submission_format.csv")

# %%
dengue_features_train.head()
# Out:
#   city  year  weekofyear week_start_date   ndvi_ne   ndvi_nw   ndvi_se  \
# 0   sj  1990          18      1990-04-30  0.122600  0.103725  0.198483
# 1   sj  1990          19      1990-05-07  0.169900  0.142175  0.162357
# 2   sj  1990          20      1990-05-14  0.032250  0.172967  0.157200
# 3   sj  1990          21      1990-05-21  0.128633  0.245067  0.227557
# 4   sj  1990          22      1990-05-28  0.196200  0.262200  0.251200
#
#     ndvi_sw  precipitation_amt_mm  reanalysis_air_temp_k        ...          \
# 0  0.177617                 12.42             297.572857        ...
# 1  0.155486                 22.82             298.211429        ...
# 2  0.170843                 34.54             298.781429        ...
# 3  0.235886                 15.36             298.987143        ...
# 4  0.247340                  7.52             299.518571        ...
#
#    reanalysis_precip_amt_kg_per_m2  reanalysis_relative_humidity_percent  \
# ...

# %%
dengue_features_test.head()
# Out:
#   city  year  weekofyear week_start_date  ndvi_ne   ndvi_nw   ndvi_se  \
# 0   sj  2008          18       4/29/2008  -0.0189 -0.018900  0.102729
# 1   sj  2008          19        5/6/2008  -0.0180 -0.012400  0.082043
# 2   sj  2008          20       5/13/2008  -0.0015       NaN  0.151083
# 3   sj  2008          21       5/20/2008      NaN -0.019867  0.124329
# 4   sj  2008          22       5/27/2008   0.0568  0.039833  0.062267
#
#     ndvi_sw  precipitation_amt_mm  reanalysis_air_temp_k        ...          \
# 0  0.091200                 78.60             298.492857        ...
# 1  0.072314                 12.56             298.475714        ...
# 2  0.091529                  3.66             299.455714        ...
# 3  0.125686                  0.00             299.690000        ...
# 4  0.075914                  0.76             299.780000        ...
#
#    reanalysis_precip_amt_kg_per_m2  reanalysis_relative_humidity_percent  \
# ...

# %%
dengue_labels_train.head()
# Out:
#   city  year  weekofyear  total_cases
# 0   sj  1990          18            4
# 1   sj  1990          19            5
# 2   sj  1990          20            4
# 3   sj  1990          21            3
# 4   sj  1990          22            6

# %%
dengue_features_train.drop("week_start_date", axis=1, inplace=True)

# %%
dengue_features_train.head()
# Out:
#   city  year  weekofyear   ndvi_ne   ndvi_nw   ndvi_se   ndvi_sw  \
# 0   sj  1990          18  0.122600  0.103725  0.198483  0.177617
# 1   sj  1990          19  0.169900  0.142175  0.162357  0.155486
# 2   sj  1990          20  0.032250  0.172967  0.157200  0.170843
# 3   sj  1990          21  0.128633  0.245067  0.227557  0.235886
# 4   sj  1990          22  0.196200  0.262200  0.251200  0.247340
#
#    precipitation_amt_mm  reanalysis_air_temp_k  reanalysis_avg_temp_k  \
# 0                 12.42             297.572857             297.742857
# 1                 22.82             298.211429             298.442857
# 2                 34.54             298.781429             298.878571
# 3                 15.36             298.987143             299.228571
# 4                  7.52             299.518571             299.664286
#
#          ...          reanalysis_precip_amt_kg_per_m2  \
# 0        ...                                    32.00
# ...

# %%
dengue_features_test.drop("week_start_date", axis=1, inplace=True)

# %%
dengue_features_test.head()
# Out:
#   city  year  weekofyear  ndvi_ne   ndvi_nw   ndvi_se   ndvi_sw  \
# 0   sj  2008          18  -0.0189 -0.018900  0.102729  0.091200
# 1   sj  2008          19  -0.0180 -0.012400  0.082043  0.072314
# 2   sj  2008          20  -0.0015       NaN  0.151083  0.091529
# 3   sj  2008          21      NaN -0.019867  0.124329  0.125686
# 4   sj  2008          22   0.0568  0.039833  0.062267  0.075914
#
#    precipitation_amt_mm  reanalysis_air_temp_k  reanalysis_avg_temp_k  \
# 0                 78.60             298.492857             298.550000
# 1                 12.56             298.475714             298.557143
# 2                  3.66             299.455714             299.357143
# 3                  0.00             299.690000             299.728571
# 4                  0.76             299.780000             299.671429
#
#          ...          reanalysis_precip_amt_kg_per_m2  \
# 0        ...                                    25.37
# ...

# %%
dengue_features_train.isnull().sum()
# Out:
# city                                       0
# year                                       0
# weekofyear                                 0
# ndvi_ne                                  194
# ndvi_nw                                   52
# ndvi_se                                   22
# ndvi_sw                                   22
# precipitation_amt_mm                      13
# reanalysis_air_temp_k                     10
# reanalysis_avg_temp_k                     10
# reanalysis_dew_point_temp_k               10
# reanalysis_max_air_temp_k                 10
# reanalysis_min_air_temp_k                 10
# reanalysis_precip_amt_kg_per_m2           10
# reanalysis_relative_humidity_percent      10
# reanalysis_sat_precip_amt_mm              13
# reanalysis_specific_humidity_g_per_kg     10
# reanalysis_tdtr_k                         10
# station_avg_temp_c                        43
# station_diur_temp_rng_c                   43
# station_max_temp_c                        20
# ...

# %%
dengue_features_train.fillna(dengue_features_train.mean(), inplace=True)
# Out:
#      city  year  weekofyear   ndvi_ne   ndvi_nw   ndvi_se   ndvi_sw  \
# 0      sj  1990          18  0.122600  0.103725  0.198483  0.177617
# 1      sj  1990          19  0.169900  0.142175  0.162357  0.155486
# 2      sj  1990          20  0.032250  0.172967  0.157200  0.170843
# 3      sj  1990          21  0.128633  0.245067  0.227557  0.235886
# 4      sj  1990          22  0.196200  0.262200  0.251200  0.247340
# 5      sj  1990          23  0.142294  0.174850  0.254314  0.181743
# 6      sj  1990          24  0.112900  0.092800  0.205071  0.210271
# 7      sj  1990          25  0.072500  0.072500  0.151471  0.133029
# 8      sj  1990          26  0.102450  0.146175  0.125571  0.123600
# 9      sj  1990          27  0.142294  0.121550  0.160683  0.202567
# 10     sj  1990          28  0.192875  0.082350  0.191943  0.152929
# 11     sj  1990          29  0.291600  0.211800  0.301200  0.280667
# 12     sj  1990          30  0.150567  0.171700  0.226900  0.214557
# ...

# %%
dengue_features_train.isnull().sum()
# Out:
# city                                     0
# year                                     0
# weekofyear                               0
# ndvi_ne                                  0
# ndvi_nw                                  0
# ndvi_se                                  0
# ndvi_sw                                  0
# precipitation_amt_mm                     0
# reanalysis_air_temp_k                    0
# reanalysis_avg_temp_k                    0
# reanalysis_dew_point_temp_k              0
# reanalysis_max_air_temp_k                0
# reanalysis_min_air_temp_k                0
# reanalysis_precip_amt_kg_per_m2          0
# reanalysis_relative_humidity_percent     0
# reanalysis_sat_precip_amt_mm             0
# reanalysis_specific_humidity_g_per_kg    0
# reanalysis_tdtr_k                        0
# station_avg_temp_c                       0
# station_diur_temp_rng_c                  0
# station_max_temp_c                       0
# station_min_temp_c                       0
# ...

# %%
dengue_features_test.isnull().sum()
# Out:
# city                                      0
# year                                      0
# weekofyear                                0
# ndvi_ne                                  43
# ndvi_nw                                  11
# ndvi_se                                   1
# ndvi_sw                                   1
# precipitation_amt_mm                      2
# reanalysis_air_temp_k                     2
# reanalysis_avg_temp_k                     2
# reanalysis_dew_point_temp_k               2
# reanalysis_max_air_temp_k                 2
# reanalysis_min_air_temp_k                 2
# reanalysis_precip_amt_kg_per_m2           2
# reanalysis_relative_humidity_percent      2
# reanalysis_sat_precip_amt_mm              2
# reanalysis_specific_humidity_g_per_kg     2
# reanalysis_tdtr_k                         2
# station_avg_temp_c                       12
# station_diur_temp_rng_c                  12
# station_max_temp_c                        3
# ...

# %%
dengue_features_test.fillna(dengue_features_test.mean(), inplace=True)
# Out:
#     city  year  weekofyear   ndvi_ne   ndvi_nw   ndvi_se   ndvi_sw  \
# 0     sj  2008          18 -0.018900 -0.018900  0.102729  0.091200
# 1     sj  2008          19 -0.018000 -0.012400  0.082043  0.072314
# 2     sj  2008          20 -0.001500  0.126803  0.151083  0.091529
# 3     sj  2008          21  0.126050 -0.019867  0.124329  0.125686
# 4     sj  2008          22  0.056800  0.039833  0.062267  0.075914
# 5     sj  2008          23 -0.044000 -0.030467  0.132000  0.083529
# 6     sj  2008          24 -0.044300 -0.024925  0.132271  0.159157
# 7     sj  2008          25  0.126050  0.082150  0.144371  0.116729
# 8     sj  2008          26  0.010800  0.049900  0.100571  0.117329
# 9     sj  2008          27  0.072667  0.106660  0.155429  0.164900
# 10    sj  2008          28 -0.046450  0.006825  0.260286  0.214729
# 11    sj  2008          29  0.126050  0.126803  0.195843  0.176157
# 12    sj  2008          30  0.208300  0.429500  0.277683  0.245650
# ...

# %%
dengue_features_test.isnull().sum()
# Out:
# city                                     0
# year                                     0
# weekofyear                               0
# ndvi_ne                                  0
# ndvi_nw                                  0
# ndvi_se                                  0
# ndvi_sw                                  0
# precipitation_amt_mm                     0
# reanalysis_air_temp_k                    0
# reanalysis_avg_temp_k                    0
# reanalysis_dew_point_temp_k              0
# reanalysis_max_air_temp_k                0
# reanalysis_min_air_temp_k                0
# reanalysis_precip_amt_kg_per_m2          0
# reanalysis_relative_humidity_percent     0
# reanalysis_sat_precip_amt_mm             0
# reanalysis_specific_humidity_g_per_kg    0
# reanalysis_tdtr_k                        0
# station_avg_temp_c                       0
# station_diur_temp_rng_c                  0
# station_max_temp_c                       0
# station_min_temp_c                       0
# ...

# %%
dengue_features_train['city'] = dengue_features_train['city'].astype("category").cat.codes
dengue_features_test['city'] = dengue_features_test['city'].astype("category").cat.codes

# %%
# from sklearn import preprocessing

# %%
# # normalize the data attributes
# normalized_X_train = preprocessing.normalize(dengue_features_train)
# # normalized_X_label_train = preprocessing.normalize(dengue_labels_train)

# normalized_X_test = preprocessing.normalize(dengue_features_test)

# %%
# import matplotlib.pyplot as plt # this is used for the plot the graph
# import seaborn as sns # used for plot interactive graph. I like it most for plot

# %%
# # compute the correlations
# dengue_features_train = dengue_features_train.corr()
# dengue_features_train = dengue_features_train.corr()
# dengue_features_train = sns.heatmap(dengue_features_train)
# plt.title('dengue Train features Correlation')

# %%
# plt.show()

# %%
# corr = dengue_features_train[features].corr()
# plt.figure(figsize=(14,14))
# sns.heatmap(corr, cbar = True,  square = True, annot=True, fmt= '.2f',annot_kws={'size': 15},
#           xticklabels= features, yticklabels= features,
#           cmap= 'coolwarm')

# %%
# def correlation(dataset, threshold):
#    """The function measures correlatino among independent variables and selects variables on the basis of provided threshold."""
#    new_df = dengue_labels_train.copy()
#    new_df = new_df.drop( "total_cases" , axis=1)
#    col_corr = set() # Set of all the names of deleted columns
#    corr_matrix = new_df.corr()
#    for i in range(len(corr_matrix.columns)):
#        for j in range(i):
#            if (corr_matrix.iloc[i, j] >= abs(threshold)) and (corr_matrix.columns[j] not in col_corr):
#                colname = corr_matrix.columns[i] # getting the name of column
#                col_corr.add(colname)
#                if colname in new_df.columns:
#                    del new_df[colname] # deleting the column from the dataset
#    features = new_df.columns.tolist()

#    return featurescorr = dengue_labels_train[features].corr()
# plt.figure(figsize=(14,14))
# sns.heatmap(corr, cbar = True,  square = True, annot=True, fmt= '.2f',annot_kws={'size': 15},
#           xticklabels= features, yticklabels= features,
#           cmap= 'coolwarm')

# %%
# plt.show()

# %%
# features = correlation(dengue_labels_train, 0.4)
# print(features)

# %%
from sklearn.model_selection import train_test_split
x = dengue_features_train
y = dengue_labels_train["total_cases"]
x_train, x_test, y_train, y_test = train_test_split(x, y,test_size = 0.28571, random_state=42)

# %%
x_train.shape
# Out:
# (1040, 23)

# %%
x_test.shape
# Out:
# (416, 23)

# %%
y_train.shape
# Out:
# (1040,)

# %%
y_test.shape
# Out:
# (416,)

# %%
# from sklearn.linear_model import LogisticRegression
# regression = LogisticRegression(max_iter = 1000)
# regression.fit(x_train, y_train )
# print("Train Accuracy:",regression.score(x_train, y_train))
# print("Test Accuracy:",regression.score(x_test, y_test))

# %%
# from sklearn.linear_model import LinearRegression
# regression = LinearRegression()
# regression.fit(x_train, y_train )
# print("Train Accuracy:",regression.score(x_train, y_train))
# print("Test Accuracy:",regression.score(x_test, y_test))

# %%
# from sklearn.neural_network import MLPRegressor
# regression = MLPRegressor()
# regression.fit(x_train, y_train )
# print("Train Accuracy:",regression.score(x_train, y_train))
# print("Test Accuracy:",regression.score(x_test, y_test))

# %%
# from sklearn.ensemble import RandomForestRegressor
# regression = RandomForestRegressor()
# regression.fit(x_train, y_train )
# print("Train Accuracy:",regression.score(x_train, y_train))
# print("Test Accuracy:",regression.score(x_test, y_test))

# %%
# from sklearn.tree import DecisionTreeRegressor
# # regression = DecisionTreeRegressor()
# regression = DecisionTreeRegressor()
# regression.fit(x_train, y_train )
# print("Train Accuracy:",regression.score(x_train, y_train))
# print("Test Accuracy:",regression.score(x_test, y_test))

# %%
# from sklearn.svm import SVR
# # regression = SVR(gamma='scale', C=1.0, epsilon=0.2)
# regression = SVR()
# regression.fit(x_train, y_train )
# print("Train Accuracy:",regression.score(x_train, y_train))
# print("Test Accuracy:",regression.score(x_test, y_test))

# %%
from sklearn.ensemble import GradientBoostingRegressor
regression = GradientBoostingRegressor(random_state=42)
regression.fit(x_train, y_train )
print("Train Accuracy:",regression.score(x_train, y_train))
print("Test Accuracy:",regression.score(x_test, y_test))
# Out:
# Train Accuracy: 0.885108899048
# Test Accuracy: 0.626981385561

# %%
# from sklearn.ensemble import BaggingRegressor
# regression = BaggingRegressor(n_estimators=10, random_state=42)
# regression.fit(x_train, y_train )
# print("Train Accuracy:",regression.score(x_train, y_train))
# print("Test Accuracy:",regression.score(x_test, y_test))

# %%
# import statsmodels.api as sm
# # poisson_res = poisson_mod.fit(method="newton")
# # poisson_mod = sm.Poisson(Y, X)
# # poisson_res = poisson_mod.fit(method="newton")
# # regression = sm()
# sm.Poisson(x_train, y_train )
# print("Train Accuracy:",regression.score(x_train, y_train))
# print("Test Accuracy:",regression.score(x_test, y_test))

# %%
y_predict=regression.predict(dengue_features_test)

# %%
y_predict.dtype
# Out:
# dtype('float64')

# %%
y_predict = y_predict.astype(int)

# %%
y_predict.dtype
# Out:
# dtype('int32')

# %%
output = dengue_features_test.iloc[:,0:3]

# %%
output.dtypes
# Out:
# city           int8
# year          int64
# weekofyear    int64
# dtype: object

# %%
output['total_cases']=y_predict

# %%
# output.city.dtype

# %%
output.to_csv('output.csv')

# %%
y_true = y_test

# %%
# y_true.head()

# %%
from sklearn.metrics import mean_absolute_error

# %%
mean_absolute_error(y_true, y_predict)
# Out:
# 26.872596153846153

# %% [markdown]
# ## 27.89903846153846 - LR

# %% [markdown]
# ## 27.884615384615383 - Log R

# %% [markdown]
# ## 28.629807692307693 - RF

# %% [markdown]
# ## 29.495192307692307 - DT
